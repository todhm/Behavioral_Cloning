# %% [markdown]
# # Load the data
#
# * I used pandas dataframe to load the model.
# * I added the left camera image and right camera image on original dataframe to augment data.

# %%
import pandas as pd
samples = pd.read_csv('../videos2/driving_log.csv',skiprows = 0)
samples.columns = ['center_path','left_path','right_path','steering_angle','throttle','break','speed']
samples[['center_path','left_path','right_path']] = samples[['center_path','left_path','right_path']].apply(lambda x : x.replace('/Users/hm/Desktop/homemaster/week13','/home/ml/'))

left_df = samples[['left_path','steering_angle']]
left_df['steering_angle'] = left_df['steering_angle'].apply(lambda x: x + 0.2)
left_df.rename(columns={'left_path':'center_path'},inplace = True)
right_df = samples[['right_path','steering_angle']]
right_df['steering_angle'] = samples['steering_angle'].apply(lambda x: x- 0.2)
right_df.rename(columns={'right_path':'center_path'},inplace = True)
total_df = pd.concat([samples[['center_path','steering_angle']],
                      left_df,right_df])
# Out:
# /Users/hm/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/hm/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pandas/core/frame.py:2834: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /Users/hm/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Explore Data
# * We can see that Majority of our data are 0 data or 0.2 or -0.2 because most of steering angle of center camera are 0 and we acquire right and left camera by  adding and subtracting 0.2 from it.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import sklearn



train_samples,validation_samples = train_test_split(total_df,test_size= 0.2)
train_samples.describe()
# Out:
#        steering_angle
# count    21854.000000
# mean        -0.016539
# std          0.240611
# min         -1.200000
# 25%         -0.200000
# 50%          0.000000
# 75%          0.200000
# max          1.200000

# %%
import matplotlib.pylab as plt
import matplotlib as mpl
# %matplotlib inline
plt.title('histogram steering angle')
train_samples['steering_angle'].plot.hist(bins = 20,stacked = True)

# %% [markdown]
# # Data Preprocessing & Augmenting
# * Here is the functions I used to augment the data

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import os
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
import sklearn



#flipping image to get more data
def flip_img(image,measurement):
    image_flipped = np.fliplr(image)
    measurement_flipped = -measurement
    return image_flipped, measurement_flipped




def random_gamma(image,gamma):
    """
    way to change brightness to add more data
    http://www.pyimagesearch.com/2015/10/05/opencv-gamma-correction/

    """
    #gamma = np.random.uniform(0.4, 1.5)
    inv_gamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** inv_gamma) * 255
                      for i in np.arange(0, 256)]).astype("uint8")

    # apply gamma correction using the lookup table
    return cv2.LUT(image, table)



def making_shadow(image):
    h, w = image.shape[0], image.shape[1]
    [x1, x2] = np.random.choice(w, 2, replace=False)
    k = h / (x2 - x1)
    b = - k * x1
    for i in range(h):
        c = int((i - b) / k)
        image[i, :c, :] = (image[i, :c, :] * .5).astype(np.int32)
    return image


#Crop the unnecessary part and resize the image
def crop_process(image):

    image = image[50:-20, :]
    image = cv2.resize(image,(64,64),cv2.INTER_AREA)

    return image

# %% [markdown]
# * Flipping Image.
#     * If we flip image our image flipped totaly horizontaly so the steering angle should multiply -1 to steering angle

# %%
#train_samples = train_samples.reset_index()
m = len(samples)
sample_idx = np.random.randint(0,m)
org_img = cv2.imread(train_samples['center_path'][sample_idx])
org_steering = train_samples['steering_angle'][sample_idx]
print('Steering angle of original image',org_steering)
plt.imshow(org_img)
# Out:
# Steering angle of original image -0.65

# %%
img,steering = flip_img(org_img,org_steering)
print('Steering angle of changed image',steering)
plt.imshow(img)
# Out:
# Steering angle of changed image 0.65

# %%
m = len(samples)
sample_idx = np.random.randint(0,m)
org_img = cv2.imread(train_samples['center_path'].iloc[sample_idx])
org_steering = train_samples['steering_angle'].iloc[sample_idx]
plt.imshow(org_img)

# %% [markdown]
# * Adjust Brightness by random_gamma function.
#     * We can adjust brightness of data by adjusting gamma value if we use lower gamma we get darker image. On the contrary if we set higher gamma value we get more bright image

# %%
img = random_gamma(org_img,0.4)
print('gamma transformed image with low gamma')
plt.imshow(img)
# Out:
# gamma transformed image with low gamma

# %%
img = random_gamma(org_img,1.5)
print('gamma transformed image with high gamma')
plt.imshow(img)
# Out:
# gamma transformed image with high gamma

# %% [markdown]
# * Making Shadow on the image
#     * Making shadow on original image by making the randomly choosed part more darker

# %%
m = len(samples)
sample_idx = np.random.randint(0,m)
org_img = cv2.imread(train_samples['center_path'].iloc[sample_idx])
org_steering = train_samples['steering_angle'].iloc[sample_idx]
plt.imshow(org_img)

# %%
img = making_shadow(org_img)
plt.imshow(img)

# %% [markdown]
# * Cropping image.
#     * Cut the unnecessary parts of the image.

# %%
m = len(samples)
sample_idx = np.random.randint(0,m)
org_img = cv2.imread(train_samples['center_path'][sample_idx])
plt.imshow(org_img)

# %%
img = crop_process(org_img)
plt.imshow(img)

# %% [markdown]
# * Functions to yield batches
#     * This functions help generate batch size data randomly

# %%
#Function to make a batch of images.
def get_next_image_files(samples,batch_size):
    total_len = len(samples)
    rnd_indices = np.random.randint(0,total_len,batch_size)
    batch_imgs = []
    for index in rnd_indices:
        img = samples.iloc[index]['center_path']
        steering_angle = samples.iloc[index]['steering_angle']
        batch_imgs.append((img,steering_angle))
    return batch_imgs


#Function to make return randomly adjusted image to augment data. 
def return_processing(img_path,steering,training = True):

    img = cv2.imread(img_path)
    coin = np.random.randint(0,2)
    if bool(coin) and training:
        img,steering = flip_img(img,steering)
    
    coin2 = np.random.randint(0,2)
    if bool(coin2) and training:
        img = random_gamma(img)
    coin2 = np.random.randint(0,2)
    if bool(coin2) and training:
        img = making_shadow(img)
    img = crop_process(img)
    return img,steering



def generator(samples,training = True,batch_size = 50):
    while 1:
        if training:
            samples = shuffle(samples)
        image_data = get_next_image_files(samples,batch_size)
        images = []
        angles = []
        for image_path,steering_angle in image_data:
            img,steering = return_processing(image_path,steering_angle)
            images.append(img)
            angles.append(steering)
        X_train = np.array(images)
        y_train = np.array(angles)
        yield (X_train,y_train)

# %% [markdown]
# # Model Structure
#     * We can verify

# %%
model = Sequential()

model.add(Lambda(lambda x: (x / 255.0) - 0.5, input_shape=(64, 64, 3)))

# starts with five convolutional and maxpooling layers
model.add(Convolution2D(24, 5, 5, border_mode='same', subsample=(2, 2)))
model.add(Activation('relu')
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(36, 5, 5, border_mode='same', subsample=(2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(48, 5, 5, border_mode='same', subsample=(2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(64, 3, 3, border_mode='same', subsample=(1, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Convolution2D(64, 3, 3, border_mode='same', subsample=(1, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1)))

model.add(Flatten())

model.add(Dense(1164))
model.add(Activation(activation_relu))

model.add(Dense(100))
model.add(Activation(activation_relu))

model.add(Dense(50))
model.add(Activation(activation_relu))

model.add(Dense(10))
model.add(Activation(activation_relu))

model.add(Dense(1))


adam = Adam(lr=1e-4)

model.compile(optimizer=adam, loss='mean_squared_error')
model = load_model('model.h5')
history = model.fit_generator(
    generator(train_samples),
    samples_per_epoch=20000,
    nb_epoch=5,
    validation_data=generator(validation_samples,False),
    nb_val_samples = len(validation_samples))
# Out:
# /Users/hm/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/hm/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2834: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
print(steering)
plt.imshow(img)
# Out:
# 0.1270879

# %%
img.shape
# Out:
# (80, 320, 3)

# %% [raw]
# from keras.models import model_from_json
# from keras.models import load_model
#
#
# model = load_model('second_model.h5')
# #training_samples = np.asarray(training_samples)
# prediction = model.predict(training_samples)

# %%
for x in train_samples[['center_path','steering_angle']].iterrows():
    print(type(x[1][0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...
